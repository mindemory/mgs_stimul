# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re

# %%
year_counts = {}
current_year = None

with open('articles_curated.txt', 'r') as f:
    for line in f:
        line = line.strip()
        if line.startswith("Year:"):
            match = re.search(r'Year: (\d{4})', line)
            if match:
                current_year = int(match.group(1))
                if current_year not in year_counts:
                    year_counts[current_year] = 0
        elif line.startswith("- Title:"):
            if current_year:
                year_counts[current_year] += 1

# %%
years = list(year_counts.keys())
counts = list(year_counts.values())

plt.figure(figsize=(10, 6))
plt.bar(years[:-1], counts[:-1], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Number of articles')
plt.show()

# %%
np.sum(counts[:-1])
# Out:
# 455
